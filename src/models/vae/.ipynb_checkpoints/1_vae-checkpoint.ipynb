# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.optim
# CODE FILES HERE
from vae import Solver

# %matplotlib inline
#plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
#plt.rcParams['image.interpolation'] = 'nearest'
#plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# supress cluttering warnings in solutions
import warnings
warnings.filterwarnings('ignore')

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cpu

# %%
# 2 layer networks for encoder and decoder
mnist_dim = 784
hidden_units = 500 # Kingma, Welling use 500 neurons, otherwise use 400
z_dim = 20 # 1000 is suggested in the paper "Tutorial on VAE" but Kingma, Welling show 20 is sufficient for MNIST
learning_rate = 1e-3
batch_size = 128
optimizer = torch.optim.Adam
epochs = 6 #0000
num_normal_plots = 2
dataset = "MNIST"

# %%
solver = Solver(optimizer, mnist_dim, hidden_units, z_dim, epochs, num_normal_plots, dataset, batch_size, learning_rate)
solver.run()
# Out:
# 0it [00:00, ?it/s]
# Downloading https://cloudstor.aarnet.edu.au/plus/index.php/s/54h3OuGJhFLwAlQ/download to ../data/EMNIST/raw/download
# 100%|█████████▉| 559292416/561583919 [02:19<00:01, 1773616.87it/s]
# Extracting zip archive
# 561586176it [02:29, 1773616.87it/s]
# Extracting ../data/EMNIST/raw/gzip/emnist-balanced-train-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-byclass-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-bymerge-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-bymerge-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-digits-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-balanced-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-byclass-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-mnist-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-bymerge-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-letters-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-digits-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-byclass-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-balanced-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-mnist-test-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-mnist-train-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-letters-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-digits-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-byclass-train-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-letters-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-bymerge-train-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-balanced-train-labels-idx1-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-digits-train-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-mnist-test-images-idx3-ubyte.gz
# Extracting ../data/EMNIST/raw/gzip/emnist-letters-train-images-idx3-ubyte.gz
# Processing byclass
# Processing bymerge
# Processing balanced
# Processing letters
# Processing digits
# Processing mnist
# Done!
# +++++ START RUN +++++
# ====> Epoch: 1 train set loss avg: 191.1735
# ====> Test set loss avg: 211.8218
# 68.45260405540466 seconds for epoch 1
# ====> Epoch: 2 train set loss avg: 161.3911
# ====> Test set loss avg: 216.3495
# 72.44595980644226 seconds for epoch 2
# ====> Epoch: 3 train set loss avg: 157.9403
# ====> Test set loss avg: 218.2239
# 74.9651939868927 seconds for epoch 3
# ====> Epoch: 4 train set loss avg: 156.2469
# ====> Test set loss avg: 214.8746
# 75.20447993278503 seconds for epoch 4
# ====> Epoch: 5 train set loss avg: 155.1888
# ====> Test set loss avg: 217.4609
# 76.62804770469666 seconds for epoch 5

# %%
# Plotting train and test losses for all epochs
xaxis = np.arange(1, epochs+1)
train_losses = list(list(zip(*solver.train_loss_history))[1])
# Plotting the train loss
plt.subplot(2, 1, 1)
plt.plot(np.arange(1, len(solver.train_loss_history)+1), train_losses, '-o')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("train loss / marginal likelihood log p(x)")
#plt.legend(['train loss'], loc='upper right')
plt.xticks(xaxis)

# Plotting the test loss
plt.subplot(2, 1, 2)
plt.plot(np.arange(1, len(solver.test_loss_history)+1), solver.test_loss_history, '-o')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("test loss/ marginal likelihood log p(x)")
#plt.legend(['test loss'], loc='upper right')
plt.xticks(xaxis)

plt.tight_layout()
plt.show()

# %%
# Plotting histogram of the latent space, given the computed \mu and \sigma
# TODO: Compute the Var(\mu(z))
x = np.linspace(-5, 5, 5000)
plot_cols = np.arange(1, num_normal_plots+1)
for idx, stats in enumerate(solver.z_stats):
    epoch, mu, std, muz = stats
    print("epoch: {}, mu(z): {}, stddev(z): {}, var(z): {}, var(\mu(z)): {}".format(\
        epoch, mu, std, np.power(std, 2), torch.var(muz).item()))
    y = (1 / (np.sqrt(2 * np.pi * np.power(std, 2)))) * \
        (np.power(np.e, -(np.power((x - mu), 2) / (2 * np.power(std, 2)))))
    plt.subplot(2, 1, plot_cols[idx])
    plt.plot(x, y)
    plt.title("epoch {}, dim(z)={}".format(epoch, z_dim))
    plt.xlabel("x")
    plt.ylabel("y")

plt.tight_layout()
plt.show()
# Out:
# epoch: 5, mu(z): 0.005478830291305639, stddev(z): 1.0498973420942261, var(z): 1.1022844289365206, var(\mu(z)): 0.00012450554640963674
# epoch: 10, mu(z): 0.0036150011087256197, stddev(z): 1.0228722492006541, var(z): 1.046267638184805, var(\mu(z)): 8.938045357353985e-05

# %%
# Monitoring the reconstruction loss (likelihood lower bound) and KL divergence
rls = list(list(zip(*solver.train_loss_history))[2])
kls = list(list(zip(*solver.train_loss_history))[3])
for epoch, train_loss, rl, kl in solver.train_loss_history:
    print("epoch: {}, train_loss: {}, recon. loss: {}, KL div.: {}".format(epoch, train_loss, rl, kl))

plt.subplot(2, 1, 1)
plt.plot(np.arange(1, len(rls)+1), rls, '-o')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Reconstruction loss/likelihood lower bound of x")
#plt.legend(['recon. loss'], loc='upper right')
plt.xticks(xaxis)

plt.subplot(2, 1, 2)
plt.plot(np.arange(1, len(kls)+1), kls, '-o')
plt.xlabel("epoch")
plt.ylabel("y")
plt.title("KL divergence of q(z|x)||p(z)")
#plt.legend(['KL div.'], loc='upper right')
plt.xticks(xaxis)

plt.tight_layout()
plt.show()
# Out:
# epoch: 1, train_loss: 188.73627399088542, recon. loss: 183.32354736328125, KL div.: 5.412867069244385
# epoch: 2, train_loss: 167.33319916992187, recon. loss: 162.0941619873047, KL div.: 5.239053726196289
# epoch: 3, train_loss: 162.42736962890626, recon. loss: 157.02264404296875, KL div.: 5.404755592346191
# epoch: 4, train_loss: 159.6972417643229, recon. loss: 154.1967315673828, KL div.: 5.500536918640137
# epoch: 5, train_loss: 157.86946137695313, recon. loss: 152.28919982910156, KL div.: 5.5802412033081055
# epoch: 6, train_loss: 156.57197086588542, recon. loss: 150.93626403808594, KL div.: 5.635737895965576

# %%
# visualize q(z|x) (latent space z)
if solver.z_dim == 2:
    labels = solver.labels.tolist()
    plt.figure(figsize=(10,8))
    plt.scatter(solver.latent_space[:,0], solver.latent_space[:,1], c=labels, edgecolors='black', cmap='hsv')
    plt.xlabel("x")
    plt.ylabel("y")
    plt.colorbar() # show color scale
else:
    print("Plot of latent space not possible as dimension of z is not 2")

# %%
# JUST TEST 

plt.rcParams['savefig.facecolor'] = "0.8"

def example_plot(ax, fontsize=12):
     ax.plot([1, 2])
     ax.locator_params(nbins=3)
     ax.set_xlabel('x-label', fontsize=fontsize)
     ax.set_ylabel('y-label', fontsize=fontsize)
     ax.set_title('Title', fontsize=fontsize)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
example_plot(ax4)
plt.tight_layout()
plt.show()
